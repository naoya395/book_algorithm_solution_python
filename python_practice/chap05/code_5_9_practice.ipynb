# %% [markdown]
# # code_5_9 演習ノート：区間分割の DP
#
# 元コード：`python_codes/chap05/code_5_9.py`
#
# 地点 `0` から `n` まで進むとき、`j` から `i` へ移動するコスト `c[j][i]` を使って最小コストを求めます。

# %% [markdown]
# ## 1. アルゴリズムとコードの詳しい解説
#
# ```python
# INF = 1 << 60
#
#
# def main() -> None:
#     n = int(input())
#     c = [[0] * (n + 1) for _ in range(n + 1)]
#     for i in range(n + 1):
#         c[i] = list(map(int, input().split()))
#
#     dp = [INF] * (n + 1)
#     dp[0] = 0
#
#     for i in range(n + 1):
#         for j in range(i):
#             dp[i] = min(dp[i], dp[j] + c[j][i])
#
#     print(dp[n])
#
#
# if __name__ == "__main__":
#     main()
# ```
#
# ### 目的
#
# 地点 `0` から `n` まで進むとき、`j` から `i` へ移動するコスト `c[j][i]` を使って最小コストを求めます。
#
# ### 変数・関数の意味
#
# - `c[j][i]`: `j` から `i` へ移動するコストです。
# - `dp[i]`: 地点 `i` までの最小コストです。
# - `j`: 直前の分割位置です。
#
# ### 処理の流れ
#
# 1. すべての `i` について、直前の位置 `j < i` を全探索して `dp[i]` を更新します。
#
# ### 計算量
#
# 時間計算量は **O(n²)** です。

# %% [markdown]
# ## 2. 問題1：大事な一部分を穴埋めしよう
#
# 次のコードの `____` を埋めて、元コードと同じ動作になるようにしてください。

# %%
INF = 1 << 60


def main() -> None:
    n = int(input())
    c = [[0] * (n + 1) for _ in range(n + 1)]
    for i in range(n + 1):
        c[i] = list(map(int, input().split()))

    dp = [INF] * (n + 1)
    dp[0] = 0

    for i in range(____):
        for j in range(___):
            ___

    print(dp[n])


if __name__ == "__main__":
    main()

# %% [markdown]
# ## 3. 回答：問題1

# %%
INF = 1 << 60


def main() -> None:
    n = int(input())
    c = [[0] * (n + 1) for _ in range(n + 1)]
    for i in range(n + 1):
        c[i] = list(map(int, input().split()))

    dp = [INF] * (n + 1)
    dp[0] = 0

    for i in range(n + 1):
        for j in range(i):
            dp[i] = min(dp[i], dp[j] + c[j][i])

    print(dp[n])


if __name__ == "__main__":
    main()

# %% [markdown]
# ## 4. 問題2：重要部分を自分で書こう
#
# 入出力や大枠を参考に、重要な処理を書いてください。
#
# ### 与えられる情報
#
# - 入力・出力は元コードと同じです。
# - `dp` や補助関数を使い、重要な更新式を自分で書いてください。

# %%
INF = 1 << 60


def main() -> None:
    n = int(input())
    c = [[0] * (n + 1) for _ in range(n + 1)]
    for i in range(n + 1):
        c[i] = list(map(int, input().split()))

    # ここに dp の初期化と更新処理を書く

    print(dp[n])


if __name__ == "__main__":
    main()

# %% [markdown]
# ## 5. 回答：問題2

# %%
INF = 1 << 60


def main() -> None:
    n = int(input())
    c = [[0] * (n + 1) for _ in range(n + 1)]
    for i in range(n + 1):
        c[i] = list(map(int, input().split()))

    dp = [INF] * (n + 1)
    dp[0] = 0

    for i in range(n + 1):
        for j in range(i):
            dp[i] = min(dp[i], dp[j] + c[j][i])

    print(dp[n])


if __name__ == "__main__":
    main()

# %% [markdown]
# ## 6. 問題3：完全に空白から書こう
#
# 何も見ずに、元コードと同じアルゴリズムを最初から書いてください。

# %%
# ここに完全なコードを書く

# %% [markdown]
# ## 7. 回答：問題3

# %%
INF = 1 << 60


def main() -> None:
    n = int(input())
    c = [[0] * (n + 1) for _ in range(n + 1)]
    for i in range(n + 1):
        c[i] = list(map(int, input().split()))

    dp = [INF] * (n + 1)
    dp[0] = 0

    for i in range(n + 1):
        for j in range(i):
            dp[i] = min(dp[i], dp[j] + c[j][i])

    print(dp[n])


if __name__ == "__main__":
    main()
