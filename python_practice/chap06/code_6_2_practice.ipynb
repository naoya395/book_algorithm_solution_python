# %% [markdown]
# # code_6_2 演習ノート：答えを二分探索するテンプレート
#
# 元コード：`python_codes/chap06/code_6_2.py`
#
# 単調な判定関数 `p(x)` が `True` になる最小の整数 `x` を探索します。

# %% [markdown]
# ## 1. アルゴリズムとコードの詳しい解説
#
# ```python
# def p(x: int) -> bool:
#     """x が条件を満たすかどうかを判定する関数。"""
#     raise NotImplementedError
#
#
# def binary_search(left: int, right: int) -> int:
#     """p(x) が True となる最小の整数 x を返す。"""
#     while right - left > 1:
#         mid = left + (right - left) // 2
#         if p(mid):
#             right = mid
#         else:
#             left = mid
#     return right
# ```
#
# ### 目的
#
# 単調な判定関数 `p(x)` が `True` になる最小の整数 `x` を探索します。
#
# ### 変数・関数の意味
#
# - `p(x)`: 条件を満たすか判定する関数です。
# - `left`: 条件を満たさない側の境界です。
# - `right`: 条件を満たす側の境界です。
# - `mid`: 調べる中央です。
#
# ### 処理の流れ
#
# 1. `p(mid)` が真なら答えは左側も含めて `mid` 以下、偽なら `mid` より右側にあります。
#
# ### 計算量
#
# 時間計算量は **O(log(探索範囲))** です。

# %% [markdown]
# ## 2. 問題1：大事な一部分を穴埋めしよう
#
# 次のコードの `____` を埋めて、元コードと同じ動作になるようにしてください。

# %%
def p(x: int) -> bool:
    """x が条件を満たすかどうかを判定する関数。"""
    raise NotImplementedError


def binary_search(left: int, right: int) -> int:
    """p(x) が True となる最小の整数 x を返す。"""
    while right - left > 1:
        mid = left + (right - left) // 2
        if ____:
            right = mid
        else:
            left = mid
    return right

# %% [markdown]
# ## 3. 回答：問題1

# %%
def p(x: int) -> bool:
    """x が条件を満たすかどうかを判定する関数。"""
    raise NotImplementedError


def binary_search(left: int, right: int) -> int:
    """p(x) が True となる最小の整数 x を返す。"""
    while right - left > 1:
        mid = left + (right - left) // 2
        if p(mid):
            right = mid
        else:
            left = mid
    return right

# %% [markdown]
# ## 4. 問題2：重要部分を自分で書こう
#
# 入出力や大枠を参考に、重要な処理を書いてください。
#
# ### 与えられる情報
#
# - 入力・出力は元コードと同じです。
# - 境界 `left`, `right`, `mid` または二分探索に関わる重要処理を自分で書いてください。

# %%
def p(x: int) -> bool:
    """x が条件を満たすかどうかを判定する関数。"""
    raise NotImplementedError


def binary_search(left: int, right: int) -> int:
    """p(x) が True となる最小の整数 x を返す。"""
    # ここに条件を満たす最小値を探す二分探索を書く

# %% [markdown]
# ## 5. 回答：問題2

# %%
def p(x: int) -> bool:
    """x が条件を満たすかどうかを判定する関数。"""
    raise NotImplementedError


def binary_search(left: int, right: int) -> int:
    """p(x) が True となる最小の整数 x を返す。"""
    while right - left > 1:
        mid = left + (right - left) // 2
        if p(mid):
            right = mid
        else:
            left = mid
    return right

# %% [markdown]
# ## 6. 問題3：完全に空白から書こう
#
# 何も見ずに、元コードと同じアルゴリズムを最初から書いてください。

# %%
# ここに完全なコードを書く

# %% [markdown]
# ## 7. 回答：問題3

# %%
def p(x: int) -> bool:
    """x が条件を満たすかどうかを判定する関数。"""
    raise NotImplementedError


def binary_search(left: int, right: int) -> int:
    """p(x) が True となる最小の整数 x を返す。"""
    while right - left > 1:
        mid = left + (right - left) // 2
        if p(mid):
            right = mid
        else:
            left = mid
    return right
