# %% [markdown]
# # code_6_1 演習ノート：配列に対する二分探索
#
# 元コード：`python_codes/chap06/code_6_1.py`
#
# ソート済み配列 `A` から `key` を探し、見つかれば添字、なければ `-1` を返します。

# %% [markdown]
# ## 1. アルゴリズムとコードの詳しい解説
#
# ```python
# N = 8
# A = [3, 5, 8, 10, 14, 17, 21, 39]
#
#
# def binary_search(key: int) -> int:
#     left = 0
#     right = len(A) - 1
#     while right >= left:
#         mid = left + (right - left) // 2
#         if A[mid] == key:
#             return mid
#         if A[mid] > key:
#             right = mid - 1
#         elif A[mid] < key:
#             left = mid + 1
#     return -1
#
#
# def main() -> None:
#     print(binary_search(10))
#     print(binary_search(3))
#     print(binary_search(39))
#
#     print(binary_search(-100))
#     print(binary_search(9))
#     print(binary_search(100))
#
#
# if __name__ == "__main__":
#     main()
# ```
#
# ### 目的
#
# ソート済み配列 `A` から `key` を探し、見つかれば添字、なければ `-1` を返します。
#
# ### 変数・関数の意味
#
# - `left`, `right`: 探索範囲の左右端です。
# - `mid`: 中央の添字です。
# - `key`: 探したい値です。
# - `A`: ソート済み配列です。
#
# ### 処理の流れ
#
# 1. 中央を見て、目的値より大きければ左半分、小さければ右半分に探索範囲を狭めます。
#
# ### 計算量
#
# 時間計算量は **O(log n)** です。

# %% [markdown]
# ## 2. 問題1：大事な一部分を穴埋めしよう
#
# 次のコードの `____` を埋めて、元コードと同じ動作になるようにしてください。

# %%
N = 8
A = [3, 5, 8, 10, 14, 17, 21, 39]


def binary_search(key: int) -> int:
    left = 0
    right = ___
    while ____:
        mid = ____
        if A[mid] == key:
            return mid
        if A[mid] > key:
            right = mid - 1
        elif A[mid] < key:
            left = mid + 1
    return -1


def main() -> None:
    print(binary_search(10))
    print(binary_search(3))
    print(binary_search(39))

    print(binary_search(-100))
    print(binary_search(9))
    print(binary_search(100))


if __name__ == "__main__":
    main()

# %% [markdown]
# ## 3. 回答：問題1

# %%
N = 8
A = [3, 5, 8, 10, 14, 17, 21, 39]


def binary_search(key: int) -> int:
    left = 0
    right = len(A) - 1
    while right >= left:
        mid = left + (right - left) // 2
        if A[mid] == key:
            return mid
        if A[mid] > key:
            right = mid - 1
        elif A[mid] < key:
            left = mid + 1
    return -1


def main() -> None:
    print(binary_search(10))
    print(binary_search(3))
    print(binary_search(39))

    print(binary_search(-100))
    print(binary_search(9))
    print(binary_search(100))


if __name__ == "__main__":
    main()

# %% [markdown]
# ## 問題：Sorted Array Search
#
# 昇順にソートされた整数列 `A` が与えられます。
#
# 整数 `key` が `A` の中に存在するなら、その要素のインデックスを出力してください。存在しないなら `-1` を出力してください。
#
# ただし、インデックスは `0` 始まりとします。
#
# ### 入力
#
# ```
# N
# A_0 A_1 ... A_{N-1}
# Q
# key_1
# key_2
# ...
# key_Q
# ```
#
# ### 出力
#
# 各 `key_i` について、`A` の中に存在するならそのインデックスを、存在しないなら `-1` を1行ずつ出力してください。
#
# ### 制約
#
# ```
# 1 <= N <= 200000
# -10^9 <= A_i <= 10^9
# A_i < A_{i+1}
# 1 <= Q <= 200000
# -10^9 <= key_i <= 10^9
# ```
#
# `A` は狭義単調増加、つまり重複のない昇順の整数列です。
#
# ### 計算量
#
# 各クエリに対して、`O(log N)` 以内で答えてください。
#
# 全体の計算量は `O(Q log N)` 以内とします。
#
# 線形探索 `O(NQ)` では制約内で間に合いません。
#
# ### 入力例
#
# ```
# 8
# 3 5 8 10 14 17 21 39
# 6
# 10
# 3
# 39
# -100
# 9
# 100
# ```
#
# ### 出力例
#
# ```
# 3
# 0
# 7
# -1
# -1
# -1
# ```
#
# ### 補足
#
# この問題では、以下の関数の中身を実装してください。
#
# ```python
# def binary_search(key: int) -> int:
#     # ここを実装する
# ```
#
# `key` が配列 `A` に存在する場合はそのインデックスを返し、存在しない場合は `-1` を返してください。

# %% [markdown]
# ## 4. 問題2：重要部分を自分で書こう
#
# 入出力や大枠を参考に、重要な処理を書いてください。
#
# ### 与えられる情報
#
# - 入力・出力は元コードと同じです。
# - 境界 `left`, `right`, `mid` または二分探索に関わる重要処理を自分で書いてください。

# %%
N = 8
A = [3, 5, 8, 10, 14, 17, 21, 39]


def binary_search(key: int) -> int:
    # ここに二分探索を書く

    return -1



def main() -> None:
    print(binary_search(10))
    print(binary_search(3))
    print(binary_search(39))

    print(binary_search(-100))
    print(binary_search(9))
    print(binary_search(100))


if __name__ == "__main__":
    main()
# Out:
# 3
# 0
# 7
# -1
# -1
# -1

# %% [markdown]
# ## 5. 回答：問題2

# %%
N = 8
A = [3, 5, 8, 10, 14, 17, 21, 39]


def binary_search(key: int) -> int:
    left = 0
    right = len(A) - 1
    while right >= left:
        mid = left + (right - left) // 2
        if A[mid] == key:
            return mid
        if A[mid] > key:
            right = mid - 1
        elif A[mid] < key:
            left = mid + 1
    return -1


def main() -> None:
    print(binary_search(10))
    print(binary_search(3))
    print(binary_search(39))

    print(binary_search(-100))
    print(binary_search(9))
    print(binary_search(100))


if __name__ == "__main__":
    main()

# %% [markdown]
# ## 6. 問題3：完全に空白から書こう
#
# 何も見ずに、元コードと同じアルゴリズムを最初から書いてください。

# %%
# ここに完全なコードを書く

# %% [markdown]
# ## 7. 回答：問題3

# %%
N = 8
A = [3, 5, 8, 10, 14, 17, 21, 39]


def binary_search(key: int) -> int:
    left = 0
    right = len(A) - 1
    while right >= left:
        mid = left + (right - left) // 2
        if A[mid] == key:
            return mid
        if A[mid] > key:
            right = mid - 1
        elif A[mid] < key:
            left = mid + 1
    return -1


def main() -> None:
    print(binary_search(10))
    print(binary_search(3))
    print(binary_search(39))

    print(binary_search(-100))
    print(binary_search(9))
    print(binary_search(100))


if __name__ == "__main__":
    main()
