# %% [markdown]
# <a href="https://colab.research.google.com/github/naoya395/book_algorithm_solution_python/blob/master/python_practice/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def insertion_sort(a):
    n = len(a)

    for i in range(1, n):
        v = a[i]

        while i > 0 and a[i - 1] > v:
            a[i] = a[i - 1]
            i -= 1

        a[i] = v

# %%
def insertion_sort(a): # for文中に値を変えると壊れるCっぽい書き方
    n = len(a)

    for i in range(1, n):
        v = a[i]
        j = i

        while j > 0 and a[j - 1] > v:
            a[j] = a[j - 1]
            j -= 1

        a[j] = v

# %%
a = [5, 2, 4, 6, 1, 3]
insertion_sort(a)
print(a)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
def merge_sort(a, left = 0, right = None):
  if right is None:
    right = len(a)
  if right - left <= 1:
    return

  mid = (left + right) // 2

  merge_sort(a, left, mid)
  merge_sort(a, mid, right)

  buf = []
  i = left
  j = right

  while i < mid and j < right:
    if a[i] <= a[j]:
      buf.append(a[i])
      i += 1
    else:
      buf.append(a[j])
      j += 1

  while i< mid:
    buf.append(a[i])
    i += 1
  while j <right:
    buf.append(a[j])
    j+=1

  for k in range(len(buf)):
    a[left + k]  = buf[k]

# %%
def merge_sort(a, left=0, right=None):
    if right is None:
        right = len(a)

    # 要素数が 0 個または 1 個なら、もうソート済み
    if right - left <= 1:
        return

    mid = (left + right) // 2

    # 左半分と右半分をそれぞれソート
    merge_sort(a, left, mid)
    merge_sort(a, mid, right)

    # 2つのソート済み配列を合体する
    buf = []
    i = left
    j = mid

    while i < mid and j < right:
        if a[i] <= a[j]:
            buf.append(a[i])
            i += 1
        else:
            buf.append(a[j])
            j += 1

    # 左側が余った場合
    while i < mid:
        buf.append(a[i])
        i += 1

    # 右側が余った場合
    while j < right:
        buf.append(a[j])
        j += 1

    # 元の配列に戻す
    for k in range(len(buf)):
        a[left + k] = buf[k]

# %%
a = [5, 2, 4, 6, 1, 3]
merge_sort(a)
print(a)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
def quick_sort(a, left=0, right=None):
    if right is None:
        right = len(a)

    # 要素数が 0 個または 1 個なら、もうソート済み
    if right - left <= 1:
        return

    # pivot を選ぶ。ここでは真ん中の値を使う
    pivot_index = (left + right) // 2
    pivot = a[pivot_index]

    # pivot を一旦右端に移動する
    a[pivot_index], a[right - 1] = a[right - 1], a[pivot_index]

    # i は「pivot 未満の値を置く場所」
    i = left

    for j in range(left, right - 1):
        if a[j] < pivot:
            a[i], a[j] = a[j], a[i]
            i += 1

    # pivot を正しい位置に置く
    a[i], a[right - 1] = a[right - 1], a[i]

    # pivot の左側と右側を再帰的にソート
    quick_sort(a, left, i)
    quick_sort(a, i + 1, right)

# %%
def quick_sort(a, left = 0, right = None):
  if right is None:
    right = len(a)

  if right - left <= 1:
    return

  pivot_index = (left + right) // 2
  pivot = a[pivot_index]

  a[pivot_index], a[right -1] = a[right -1], a[pivot_index]

  i = left

  for j in range(left, right -1):
    if a[j] < pivot:
      a[i], a[j] = a[j], a[i]
      i+=1

  a[i] , a[right -1] - a[right -1], a[i]

  quick_sort(a, left, i)
  quick_sort(a, i + 1, right)

# %%
a = [5, 2, 4, 6, 1, 3]
quick_sort(a)
print(a)
# Out:
# [1, 2, 3, 4, 5, 6]
